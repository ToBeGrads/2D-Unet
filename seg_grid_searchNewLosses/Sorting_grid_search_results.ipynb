# %%
# sorting the experiments 
import pandas as pd 


grid = pd.read_csv("/home/jovyan/2DUNet/seg_grid_searchNewLosses/grid_search_3d_summary.csv")
grid.head()
# Out:
#    Val_STN_Dice_2D  Val_RN_Dice_2D  Val_Loss  Test_STN_Dice_2D  \
# 0           0.8114          0.7748    0.3491            0.8347
# 1           0.8106          0.7641    0.0585            0.8192
# 2           0.8101          0.0175    0.5152            0.8116
# 3           0.8091          0.7695    0.0534            0.8056
# 4           0.8090          0.7527    0.3556            0.8287
#
#    Test_RN_Dice_2D  Test_Loss  STN_val_mean_dice  STN_val_std_dice  \
# 0           0.8173     0.3105             0.8014            0.0735
# 1           0.8211     0.0404             0.8046            0.0766
# 2           0.0150     0.5149             0.8031            0.0843
# 3           0.8275     0.0400             0.7996            0.0847
# 4           0.8437     0.2867             0.7965            0.0859
#
#    STN_val_mean_hd95  STN_val_std_hd95  ...  RN_test_mean_iou  \
# 0               1.48              0.79  ...            0.6911
# ...

# %%
stn_grid = grid.sort_values(
    by=[
        "STN_val_mean_dice",
        "STN_val_mean_hd95",
        "STN_val_mean_precision",
    ],
    ascending=[
        False,
        True, 
        False
    ]
)

stn_dice_grid = grid.sort_values(
    by=[
        "STN_val_mean_dice",
    ],
    ascending=False
)

stn_hd95_grid = grid.sort_values(
    by=[
        "STN_val_mean_hd95",
    ],
    ascending=True
)

stn_precision_grid = grid.sort_values(
    by=[
        "STN_val_mean_precision",
    ],
    ascending=False
)
cols = [
    "Loss_Type", "Features", "Learning_Rate", "Weight_Decay",
    "Dropout", "Only_Annotated", "CE_Weight", "FT_Weight",
    "STN_val_mean_dice", "STN_val_std_dice",
    "STN_val_mean_hd95", "STN_val_std_hd95"
]
print("\nBest results sorting STN_val_mean_dice, STN_val_mean_hd95, STN_val_mean_precision")
for i, row in stn_grid.head(1).iterrows():
    print(f"STN best {i}")
    print(f"Loss_Type: {row['Loss_Type']}")
    print(f"Features: {row['Features']}")
    print(f"Learning_Rate: {row['Learning_Rate']}")
    print(f"Weight_Decay: {row['Weight_Decay']}")
    print(f"Dropout: {row['Dropout']}")
    print(f"Only_Annotated: {row['Only_Annotated']}")
    print(f"CE_Weight: {row['CE_Weight']}")
    print(f"FT_Weight: {row['FT_Weight']}")
    print(f"Dice mean ± std: {row['STN_val_mean_dice']} ± {row['STN_val_std_dice']}")
    print(f"HD95 mean ± std: {row['STN_val_mean_hd95']} ± {row['STN_val_std_hd95']}")
    print(f"Precision mean ± std: {row['STN_val_mean_precision']} ± {row['STN_val_std_precision']} \n")


print("\nBest results sorting STN_val_mean_dice")
for i, row in stn_dice_grid.head(1).iterrows():
    print(f"STN best {i}")
    print(f"Loss_Type: {row['Loss_Type']}")
    print(f"Features: {row['Features']}")
    print(f"Learning_Rate: {row['Learning_Rate']}")
    print(f"Weight_Decay: {row['Weight_Decay']}")
    print(f"Dropout: {row['Dropout']}")
    print(f"Only_Annotated: {row['Only_Annotated']}")
    print(f"CE_Weight: {row['CE_Weight']}")
    print(f"FT_Weight: {row['FT_Weight']}")
    print(f"Dice mean ± std: {row['STN_val_mean_dice']} ± {row['STN_val_std_dice']}")
    print(f"HD95 mean ± std: {row['STN_val_mean_hd95']} ± {row['STN_val_std_hd95']}")
    print(f"Precision mean ± std: {row['STN_val_mean_precision']} ± {row['STN_val_std_precision']} \n")


print("\nBest results sorting STN_val_mean_hd95")
for i, row in stn_hd95_grid.head(1).iterrows():
    print(f"STN best {i}")
    print(f"Loss_Type: {row['Loss_Type']}")
    print(f"Features: {row['Features']}")
    print(f"Learning_Rate: {row['Learning_Rate']}")
    print(f"Weight_Decay: {row['Weight_Decay']}")
    print(f"Dropout: {row['Dropout']}")
    print(f"Only_Annotated: {row['Only_Annotated']}")
    print(f"CE_Weight: {row['CE_Weight']}")
    print(f"FT_Weight: {row['FT_Weight']}")
    print(f"Dice mean ± std: {row['STN_val_mean_dice']} ± {row['STN_val_std_dice']}")
    print(f"HD95 mean ± std: {row['STN_val_mean_hd95']} ± {row['STN_val_std_hd95']}")
    print(f"Precision mean ± std: {row['STN_val_mean_precision']} ± {row['STN_val_std_precision']} \n")


print("\nBest results sorting STN_val_mean_precision")
for i, row in stn_precision_grid.head(1).iterrows():
    print(f"STN best {i}")
    print(f"Loss_Type: {row['Loss_Type']}")
    print(f"Features: {row['Features']}")
    print(f"Learning_Rate: {row['Learning_Rate']}")
    print(f"Weight_Decay: {row['Weight_Decay']}")
    print(f"Dropout: {row['Dropout']}")
    print(f"Only_Annotated: {row['Only_Annotated']}")
    print(f"CE_Weight: {row['CE_Weight']}")
    print(f"FT_Weight: {row['FT_Weight']}")
    print(f"Dice mean ± std: {row['STN_val_mean_dice']} ± {row['STN_val_std_dice']}")
    print(f"HD95 mean ± std: {row['STN_val_mean_hd95']} ± {row['STN_val_std_hd95']}")
    print(f"Precision mean ± std: {row['STN_val_mean_precision']} ± {row['STN_val_std_precision']} \n")
# Out:
# Best results sorting STN_val_mean_dice, STN_val_mean_hd95, STN_val_mean_precision
# STN best 7
# Loss_Type: UnifiedFocal
# Features: [64, 128, 256, 512]
# Learning_Rate: 0.0005
# Weight_Decay: 0.0001
# Dropout: 0.4
# Only_Annotated: True
# CE_Weight: 0.1
# FT_Weight: 0.9
# Dice mean ± std: 0.8053 ± 0.0852
# HD95 mean ± std: 1.25 ± 0.75
# Precision mean ± std: 0.7928 ± 0.111
#
#
# Best results sorting STN_val_mean_dice
# STN best 7
# Loss_Type: UnifiedFocal
# Features: [64, 128, 256, 512]
# Learning_Rate: 0.0005
# Weight_Decay: 0.0001
# Dropout: 0.4
# Only_Annotated: True
# CE_Weight: 0.1
# FT_Weight: 0.9
# Dice mean ± std: 0.8053 ± 0.0852
# HD95 mean ± std: 1.25 ± 0.75
# Precision mean ± std: 0.7928 ± 0.111
#
#
# Best results sorting STN_val_mean_hd95
# STN best 8
# Loss_Type: UnifiedFocal
# Features: [32, 64, 128, 256]
# Learning_Rate: 0.0005
# Weight_Decay: 0.0001
# Dropout: 0.4
# Only_Annotated: True
# CE_Weight: 0.3
# FT_Weight: 0.7
# Dice mean ± std: 0.8049 ± 0.0839
# ...

# %%
rn_grid = grid.sort_values(
    by=[
        "RN_val_mean_dice",
        "RN_val_mean_hd95",
        "RN_val_mean_precision",
    ],
    ascending=[
        False,
        True, 
        False
    ]
)

rn_dice_grid = grid.sort_values(
    by=[
        "RN_val_mean_dice",
    ],
    ascending=False
)

rn_hd95_grid = grid.sort_values(
    by=[
        "RN_val_mean_hd95",
    ],
    ascending=True
)

rn_precision_grid = grid.sort_values(
    by=[
        "RN_val_mean_precision",
    ],
    ascending=False
)
cols = [
    "Loss_Type", "Features", "Learning_Rate", "Weight_Decay",
    "Dropout", "Only_Annotated", "CE_Weight", "FT_Weight",
    "RN_val_mean_dice", "RN_val_std_dice",
    "RN_val_mean_hd95", "RN_val_std_hd95"
]
print("\nBest results sorting RN_val_mean_dice, RN_val_mean_hd95, RN_val_mean_precision")
for i, row in rn_grid.head(1).iterrows():
    print(f"STN best {i}")
    print(f"Loss_Type: {row['Loss_Type']}")
    print(f"Features: {row['Features']}")
    print(f"Learning_Rate: {row['Learning_Rate']}")
    print(f"Weight_Decay: {row['Weight_Decay']}")
    print(f"Dropout: {row['Dropout']}")
    print(f"Only_Annotated: {row['Only_Annotated']}")
    print(f"CE_Weight: {row['CE_Weight']}")
    print(f"FT_Weight: {row['FT_Weight']}")
    print(f"Dice mean ± std: {row['RN_val_mean_dice']} ± {row['RN_val_std_dice']}")
    print(f"HD95 mean ± std: {row['RN_val_mean_hd95']} ± {row['RN_val_std_hd95']}")
    print(f"Precision mean ± std: {row['RN_val_mean_precision']} ± {row['RN_val_std_precision']} \n")


print("\nBest results sorting RN_val_mean_dice")
for i, row in rn_dice_grid.head(1).iterrows():
    print(f"STN best {i}")
    print(f"Loss_Type: {row['Loss_Type']}")
    print(f"Features: {row['Features']}")
    print(f"Learning_Rate: {row['Learning_Rate']}")
    print(f"Weight_Decay: {row['Weight_Decay']}")
    print(f"Dropout: {row['Dropout']}")
    print(f"Only_Annotated: {row['Only_Annotated']}")
    print(f"CE_Weight: {row['CE_Weight']}")
    print(f"FT_Weight: {row['FT_Weight']}")
    print(f"Dice mean ± std: {row['RN_val_mean_dice']} ± {row['RN_val_std_dice']}")
    print(f"HD95 mean ± std: {row['RN_val_mean_hd95']} ± {row['RN_val_std_hd95']}")
    print(f"Precision mean ± std: {row['RN_val_mean_precision']} ± {row['RN_val_std_precision']} \n")


print("\nBest results sorting RN_val_mean_hd95")
for i, row in rn_hd95_grid.head(1).iterrows():
    print(f"STN best {i}")
    print(f"Loss_Type: {row['Loss_Type']}")
    print(f"Features: {row['Features']}")
    print(f"Learning_Rate: {row['Learning_Rate']}")
    print(f"Weight_Decay: {row['Weight_Decay']}")
    print(f"Dropout: {row['Dropout']}")
    print(f"Only_Annotated: {row['Only_Annotated']}")
    print(f"CE_Weight: {row['CE_Weight']}")
    print(f"FT_Weight: {row['FT_Weight']}")
    print(f"Dice mean ± std: {row['RN_val_mean_dice']} ± {row['RN_val_std_dice']}")
    print(f"HD95 mean ± std: {row['RN_val_mean_hd95']} ± {row['RN_val_std_hd95']}")
    print(f"Precision mean ± std: {row['RN_val_mean_precision']} ± {row['RN_val_std_precision']} \n")


print("\nBest results sorting RN_val_mean_precision")
for i, row in rn_precision_grid.head(1).iterrows():
    print(f"STN best {i}")
    print(f"Loss_Type: {row['Loss_Type']}")
    print(f"Features: {row['Features']}")
    print(f"Learning_Rate: {row['Learning_Rate']}")
    print(f"Weight_Decay: {row['Weight_Decay']}")
    print(f"Dropout: {row['Dropout']}")
    print(f"Only_Annotated: {row['Only_Annotated']}")
    print(f"CE_Weight: {row['CE_Weight']}")
    print(f"FT_Weight: {row['FT_Weight']}")
    print(f"Dice mean ± std: {row['RN_val_mean_dice']} ± {row['RN_val_std_dice']}")
    print(f"HD95 mean ± std: {row['RN_val_mean_hd95']} ± {row['RN_val_std_hd95']}")
    print(f"Precision mean ± std: {row['RN_val_mean_precision']} ± {row['RN_val_std_precision']} \n")
# Out:
# Best results sorting RN_val_mean_dice, RN_val_mean_hd95, RN_val_mean_precision
# STN best 33
# Loss_Type: FocalTversky
# Features: [64, 128, 256, 512]
# Learning_Rate: 0.0005
# Weight_Decay: 0.01
# Dropout: 0.2
# Only_Annotated: True
# CE_Weight: 0.1
# FT_Weight: 0.9
# Dice mean ± std: 0.8036 ± 0.0233
# HD95 mean ± std: 1.05 ± 0.29
# Precision mean ± std: 0.8266 ± 0.1046
#
#
# Best results sorting RN_val_mean_dice
# STN best 33
# Loss_Type: FocalTversky
# Features: [64, 128, 256, 512]
# Learning_Rate: 0.0005
# Weight_Decay: 0.01
# Dropout: 0.2
# Only_Annotated: True
# CE_Weight: 0.1
# FT_Weight: 0.9
# Dice mean ± std: 0.8036 ± 0.0233
# HD95 mean ± std: 1.05 ± 0.29
# Precision mean ± std: 0.8266 ± 0.1046
#
#
# Best results sorting RN_val_mean_hd95
# STN best 5
# Loss_Type: UnifiedFocal
# Features: [64, 128, 256, 512]
# Learning_Rate: 0.0005
# Weight_Decay: 0.01
# Dropout: 0.4
# Only_Annotated: True
# CE_Weight: 0.1
# FT_Weight: 0.9
# Dice mean ± std: 0.7817 ± 0.0342
# ...
